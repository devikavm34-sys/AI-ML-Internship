# %%
import pandas as pd

# %%
data={'Name':['Alice','Bob'],'Age':[25,30]}
df=pd.DataFrame(data)

# %%
lst=[['Alice',25],['Bob',30]]
df=pd.DataFrame(lst,columns=['Name','Age'])

# %%
df.head()
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
df.tail()
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    2 non-null      str
#  1   Age     2 non-null      int64
# dtypes: int64(1), str(1)
# memory usage: 164.0 bytes

# %%
df.describe()
# Out:
#              Age
# count   2.000000
# mean   27.500000
# std     3.535534
# min    25.000000
# 25%    26.250000
# 50%    27.500000
# 75%    28.750000
# max    30.000000

# %%
df['Name']
# Out:
# 0    Alice
# 1      Bob
# Name: Name, dtype: str

# %%
df[['Name','Age']]
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
df.loc[0]
# Out:
# Name    Alice
# Age        25
# Name: 0, dtype: object

# %%
df.iloc[1]
# Out:
# Name    Bob
# Age      30
# Name: 1, dtype: object

# %%
df[df['Age']>25]
# Out:
#   Name  Age
# 1  Bob   30

# %%
df['Gender']=['F','M']
df.drop('Gender',axis=1, inplace=True)

# %%
df.isnull()
# Out:
#     Name    Age
# 0  False  False
# 1  False  False

# %%
df.dropna()
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
df.fillna(0)
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
df['Age'] = [25, 30]
print(df)
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30

# %%
df.groupby('Name')['Age'].mean()
# Out:
# Name
# Alice    25.0
# Bob      30.0
# Name: Age, dtype: float64

# %%
df1 = pd.DataFrame({
    'ID': [1, 2, 3],
    'Name': ['Alice', 'Bob', 'Charlie']
})
df2 = pd.DataFrame({
    'ID': [1, 2, 3],
    'Marks': [85, 90, 78]
})
pd.merge(df1, df2, on='ID')
# Out:
#    ID     Name  Marks
# 0   1    Alice     85
# 1   2      Bob     90
# 2   3  Charlie     78

# %%
df1 = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie']
})
df2 = pd.DataFrame({
    'Marks': [85, 90, 78]
})
df1.join(df2)
# Out:
#       Name  Marks
# 0    Alice     85
# 1      Bob     90
# 2  Charlie     78

# %%
import os
print(os.getcwd())
print(os.listdir())
# Out:
# C:\Users\DEVIKA VM\OneDrive\Desktop\AIML
# ['.ipynb_checkpoints', 'array.npy', 'numpy', 'Untitled Folder', 'Untitled.ipynb', 'Untitled1.ipynb', 'Untitled2.ipynb', 'Untitled3.ipynb', 'Untitled4.ipynb']

# %%
import pandas as pd

data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Marks': [85, 90, 78]
}

df = pd.DataFrame(data)

df.to_csv('output.csv', index=False)

print("output.csv created")
# Out:
# output.csv created

# %%
import os
print(os.path.exists('output.csv'))
# Out:
# True

# %%
df = pd.read_csv('output.csv')
print(df)
# Out:
#       Name  Marks
# 0    Alice     85
# 1      Bob     90
# 2  Charlie     78

# %%
df.to_csv('output.csv',index=False)
print(df)
# Out:
#       Name  Marks
# 0    Alice     85
# 1      Bob     90
# 2  Charlie     78

# %%
df.sort_values('Marks')
# Out:
#       Name  Marks
# 2  Charlie     78
# 0    Alice     85
# 1      Bob     90

# %%
df['Marks'].apply(lambda x: x+1)
# Out:
# 0    86
# 1    91
# 2    79
# Name: Marks, dtype: int64

# %%
df['Name'].unique()
# Out:
# <StringArray>
# ['Alice', 'Bob', 'Charlie']
# Length: 3, dtype: str

# %%
df['Marks'].value_counts()
# Out:
# Marks
# 85    1
# 90    1
# 78    1
# Name: count, dtype: int64
